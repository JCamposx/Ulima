# %%
import pandas as pd # Librería para lectura de ficheros

# %%
# Leer fichero csv
csv = pd.read_csv("./california_housing_train.csv")

# %%
# Mostrar el csv leido
csv
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Mostrar los elementos del csv desde n hasta m-1
csv[0:9]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# ...

# %%
# Mostrar solo la primera parte del csv
csv.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Mostrar la columna llamada "longitude"
csv.longitude
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64

# %%
# Mostrar solo la fila 0 del csv
csv.iloc[0]
# Out:
# longitude              -114.3100
# latitude                 34.1900
# housing_median_age       15.0000
# total_rooms            5612.0000
# total_bedrooms         1283.0000
# population             1015.0000
# households              472.0000
# median_income             1.4936
# median_house_value    66900.0000
# Name: 0, dtype: float64

# %%
# Mostrar análisis estadísdicos por cada valor númerico del csv
csv.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# Identifica si las celdas del csv están vacías
csv.isna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
# Contando el isna(), podemos identificar si a alguno de los items del csv le
# falta algún dato
csv.isna().count()
# Out:
# longitude             17000
# latitude              17000
# housing_median_age    17000
# total_rooms           17000
# total_bedrooms        17000
# population            17000
# households            17000
# median_income         17000
# median_house_value    17000
# dtype: int64

# %%
# Eliminamos todos los items que contengan un na (vacío)
csv.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Eliminamos una columna
csv.drop(columns="latitude")
# Out:
#        longitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        -114.31                15.0       5612.0          1283.0      1015.0
# 1        -114.47                19.0       7650.0          1901.0      1129.0
# 2        -114.56                17.0        720.0           174.0       333.0
# 3        -114.57                14.0       1501.0           337.0       515.0
# 4        -114.57                20.0       1454.0           326.0       624.0
# ...          ...                 ...          ...             ...         ...
# 16995    -124.26                52.0       2217.0           394.0       907.0
# 16996    -124.27                36.0       2349.0           528.0      1194.0
# 16997    -124.30                17.0       2677.0           531.0      1244.0
# 16998    -124.30                19.0       2672.0           552.0      1298.0
# 16999    -124.35                52.0       1820.0           300.0       806.0
#
# ...

# %%
# Ordenar el csv respecto a un item de manera descendente
csv.sort_values(by="population", ascending=False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2274     -117.42     33.35                14.0      25135.0          4819.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# ...          ...       ...                 ...          ...             ...
# 288      -116.76     34.14                 4.0         42.0            10.0
# 14105    -122.06     37.39                26.0         18.0             4.0
# 2907     -117.76     35.22                 4.0         18.0             3.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 8232     -118.44     34.04                16.0         18.0             6.0
#
# ...
